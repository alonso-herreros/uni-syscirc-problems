# %%
from sympy import *
from syscirc.funcs import u
from syscirc.plot import plotcont
from syscirc.convolution import convolution_s

# %%
def x(t:float):
    return sin(pi*t)*u(t)*u(2-t)

plotcont(x, [-1,3], 0.01)

# %%
def h(t:float):
    return 2*u(t-1)*u(3-t)

plotcont(h, [0,4], 0.01)

# %%
y = convolution_s(x, h)
plotcont(y, [0, 6], 0.05)

# %%
t = Symbol("t")
ym = Piecewise((0, t<1), (1, t<3), (-1, t<5), (0, True))*2/pi*(1+cos(pi*t))
ym
# Out:
# 2*(cos(pi*t) + 1)*Piecewise((0, t < 1), (1, t < 3), (-1, t < 5), (0, True))/pi

# %%
plotcont([y, ym+0.05], [0,6], 0.05)

# %%
y.subs(t, 4)
# Out:
# -4/pi
